# %%
# %run ./scripts/landscapes.py
# %run ./scripts/shared.py
# %run ./scripts/graphs.py
# %run ./scripts/pareto.py
CONSTANTS['SHOW_TITLE'] = False

# %%
data = plot_pareto('kernel-kmeans', 2, 'bioavailability', 2)

# %%
data = plot_pareto('kmeans', 2, 'bioavailability', 2)

# %%
data = plot_pareto('kernel-kmeans', 3, 'vladislavleva-1', 2)

# %%
data = plot_pareto('kmeans', 3, 'vladislavleva-1', 2)
