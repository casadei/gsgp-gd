# %%
# %run ./scripts/landscapes.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-611-b0431ac571ce> in <module>()
#       1 get_ipython().magic('run ./scripts/landscapes.py')
# ----> 2 Utils
#
# NameError: name 'Utils' is not defined

# %%
render(RenderType.GROUPS, 'single-objective', 1, 'vladislavleva-1', DatasetType.TEST, CONSTANTS['COLORS'], 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-609-2830033e86c0> in <module>()
# ----> 1 render(RenderType.GROUPS, 'single-objective', 1, 'vladislavleva-1', DatasetType.TEST, CONSTANTS['COLORS'], 2)
#
# /Users/casadei/development/casadei/gsgp-mo/reports/scripts/landscapes.py in render(type, strategy, k, dataset, datasetType, colors, execution)
#     123
#     124 def render(type, strategy, k, dataset, datasetType, colors, execution = 1):
# --> 125   directory = Util.directory_path(strategy, k, dataset)
#     126   filename = "%s/groups-%02d.txt" % (directory, execution)
#     127
#
# NameError: name 'Util' is not defined

# %%
render(RenderType.ERRORS, 'kernel-kmeans', 5, 'keijzer-7', DatasetType.TEST, CONSTANTS['COLORS'], 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-556-1beda20c47eb> in <module>()
# ----> 1 render(RenderType.ERRORS, 'kernel-kmeans', 5, 'keijzer-7', DatasetType.TEST, CONSTANTS['COLORS'], 1)
#
# /Users/casadei/development/casadei/gsgp-mo/reports/scripts/landscapes.py in render(type, strategy, k, dataset, datasetType, colors, execution)
#     147     title = "individuals using %s" % (strategy)
#     148   if type == RenderType.ERRORS:
# --> 149     matrix = build_errors_data(data, datasetType, directory, execution)
#     150     title = "Errors using %s" % (strategy)
#     151   elif type == RenderType.GROUPS:
#
# /Users/casadei/development/casadei/gsgp-mo/reports/scripts/landscapes.py in build_errors_data(data, datasetType, directory, execution)
#     106
#     107 def build_errors_data(data, datasetType, directory, execution):
# --> 108   file = 'trOutputs.csv' if datasetType == DatasetType.TRAINING else 'tsOutputs.csv'
#     109
#     110   semantics = select_execution(
#
# NameError: name 'DatasetType' is not defined

# %%
render(RenderType.ERRORS, 'random-without-replacement', 2, 'vladislavleva-1', DatasetType.TEST, CONSTANTS['COLORS'], 1)

# %%
render(RenderType.INDIVIDUALS, 'kernel-kmeans', 3, 'vladislavleva-1', DatasetType.TEST, CONSTANTS['COLORS'], 1)
